# %%
#importaciones de las librerias
import pandas as pd
import numpy as np
import sklearn as sl
import matplotlib.pyplot as plt
import mlxtend as mx
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
data=pd.read_csv("Estudiantes.csv")#Leemos el fichero csv
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Parte 1
# ## Haz el preprocesamiento necesario para generar el DataFrame de entrada donde las 3 columnas de puntuación estén categorizadas en 4 clases diferentes (muy baja, baja, media y alta) con rangos de 25 puntos.

# %%
#Agrupa la columna de día del mes de manera que cada uno corresponda a una semana usando una etiqueta de tipo String.
conditionlist = [
    (data['math score'] >= 0) & (data['math score'] <=25),
    (data['math score'] >= 26) & (data['math score'] <=51),
    (data['math score'] >= 52) & (data['math score'] <=77),
    (data['math score'] > 78)]
choicelist = ['muy bajam', 'bajam', 'mediam','altam']
data['math score'] = np.select(conditionlist, choicelist, default='Not Specified')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none     mediam             72             74
# 1                 completed     mediam             90             88
# 2                      none      altam             95             93
# 3                      none      bajam             57             44
# 4                      none     mediam             78             75
# ..                      ...        ...            ...            ...
# 995               completed      altam             99             95
# 996                    none     mediam             55             55
# 997               completed     mediam             71             65
# 998               completed     mediam             78             77
# 999                    none     mediam             86             86
#
# [1000 rows x 8 columns]

# %%
conditionlist = [
    (data['reading score'] >= 0) & (data['reading score'] <=25),
    (data['reading score'] >= 26) & (data['reading score'] <=50),
    (data['reading score'] >= 51) & (data['reading score'] <=76),
    (data['reading score'] > 76)]
choicelist = ['muy bajar', 'bajar', 'mediar','altar']
data['reading score'] = np.select(conditionlist, choicelist, default='Not Specified')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score reading score  writing score
# 0                      none     mediam        mediar             74
# 1                 completed     mediam         altar             88
# 2                      none      altam         altar             93
# 3                      none      bajam        mediar             44
# 4                      none     mediam         altar             75
# ..                      ...        ...           ...            ...
# 995               completed      altam         altar             95
# 996                    none     mediam        mediar             55
# 997               completed     mediam        mediar             65
# 998               completed     mediam         altar             77
# 999                    none     mediam         altar             86
#
# [1000 rows x 8 columns]

# %%
conditionlist = [
    (data['writing score'] >= 0) & (data['writing score'] <=25),
    (data['writing score'] >= 26) & (data['writing score'] <=50),
    (data['writing score'] >= 51) & (data['writing score'] <=76),
    (data['writing score'] > 76)]
choicelist = ['muy bajaw', 'bajaw', 'mediaw','altaw']
data['writing score'] = np.select(conditionlist, choicelist, default='Not Specified')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score reading score writing score
# 0                      none     mediam        mediar        mediaw
# 1                 completed     mediam         altar         altaw
# 2                      none      altam         altar         altaw
# 3                      none      bajam        mediar         bajaw
# 4                      none     mediam         altar        mediaw
# ..                      ...        ...           ...           ...
# 995               completed      altam         altar         altaw
# 996                    none     mediam        mediar        mediaw
# 997               completed     mediam        mediar        mediaw
# 998               completed     mediam         altar         altaw
# 999                    none     mediam         altar         altaw
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Prueba al menos tres configuraciones de soporte y frecuencia para cada tipo de puntuación.

# %%
#Escogemos las columnos que hacen referencia a los scores
datos=data.iloc[:,5:8]
datos=np.array(datos)
datos
# Out:
# array([['mediam', 'mediar', 'mediaw'],
#        ['mediam', 'altar', 'altaw'],
#        ['altam', 'altar', 'altaw'],
#        ...,
#        ['mediam', 'mediar', 'mediaw'],
#        ['mediam', 'altar', 'altaw'],
#        ['mediam', 'altar', 'altaw']], dtype=object)

# %%
#Transformamos en transacciones
te = TransactionEncoder()
te_ary = te.fit(datos).transform(datos)
df = pd.DataFrame(te_ary, columns=te.columns_)
df=df.drop(columns='Not Specified')

# %% [markdown]
# ## Primera Configuracion

# %%
#Utilizamos el algoritmo de apriori 
association_rules1 = apriori(df, min_support=0.001,use_colnames=True)
association_rules1['length']=association_rules1['itemsets'].apply(lambda x: len(x))
association_rules1['frecuencia']=association_rules1['support']*len(data.index)
association_rules1
# Out:
#     support                           itemsets  length  frecuencia
# 0     0.215                            (altam)       1       215.0
# 1     0.319                            (altar)       1       319.0
# 2     0.303                            (altaw)       1       303.0
# 3     0.154                            (bajam)       1       154.0
# 4     0.093                            (bajar)       1        93.0
# ..      ...                                ...     ...         ...
# 57    0.005          (bajar, bajaw, muy bajam)       3         5.0
# 58    0.007            (mediam, bajar, mediaw)       3         7.0
# 59    0.021            (mediam, bajaw, mediar)       3        21.0
# 60    0.394           (mediam, mediaw, mediar)       3       394.0
# 61    0.002  (muy bajaw, muy bajar, muy bajam)       3         2.0
#
# [62 rows x 4 columns]

# %% [markdown]
# ## Segunda Configuracion

# %%
association_rules2 = apriori(df, min_support=0.01,use_colnames=True)
association_rules2['length']=association_rules2['itemsets'].apply(lambda x: len(x))
association_rules2['frecuencia']=association_rules2['support']*len(data.index)
association_rules2
# Out:
#     support                  itemsets  length  frecuencia
# 0     0.215                   (altam)       1       215.0
# 1     0.319                   (altar)       1       319.0
# 2     0.303                   (altaw)       1       303.0
# 3     0.154                   (bajam)       1       154.0
# 4     0.093                   (bajar)       1        93.0
# 5     0.119                   (bajaw)       1       119.0
# 6     0.610                  (mediam)       1       610.0
# 7     0.584                  (mediar)       1       584.0
# 8     0.573                  (mediaw)       1       573.0
# 9     0.173            (altam, altar)       2       173.0
# 10    0.160            (altam, altaw)       2       160.0
# 11    0.042           (altam, mediar)       2        42.0
# 12    0.055           (altam, mediaw)       2        55.0
# 13    0.264            (altaw, altar)       2       264.0
# 14    0.135           (mediam, altar)       2       135.0
# 15    0.055           (mediaw, altar)       2        55.0
# 16    0.132           (mediam, altaw)       2       132.0
# 17    0.039           (altaw, mediar)       2        39.0
# 18    0.059            (bajar, bajam)       2        59.0
# 19    0.071            (bajaw, bajam)       2        71.0
# 20    0.093           (mediar, bajam)       2        93.0
# 21    0.079           (mediaw, bajam)       2        79.0
# 22    0.080            (bajaw, bajar)       2        80.0
# 23    0.029           (mediam, bajar)       2        29.0
# 24    0.012           (bajar, mediaw)       2        12.0
# 25    0.043           (mediam, bajaw)       2        43.0
# 26    0.039           (bajaw, mediar)       2        39.0
# 27    0.446          (mediam, mediar)       2       446.0
# 28    0.435          (mediam, mediaw)       2       435.0
# 29    0.506          (mediaw, mediar)       2       506.0
# 30    0.153     (altaw, altam, altar)       3       153.0
# 31    0.020    (mediaw, altam, altar)       3        20.0
# 32    0.035   (altam, mediaw, mediar)       3        35.0
# 33    0.101    (altaw, mediam, altar)       3       101.0
# 34    0.034   (mediam, mediaw, altar)       3        34.0
# 35    0.031   (mediam, altaw, mediar)       3        31.0
# 36    0.053     (bajaw, bajar, bajam)       3        53.0
# 37    0.018    (bajaw, mediar, bajam)       3        18.0
# 38    0.074   (mediar, mediaw, bajam)       3        74.0
# 39    0.022    (mediam, bajaw, bajar)       3        22.0
# 40    0.021   (mediam, bajaw, mediar)       3        21.0
# 41    0.394  (mediam, mediaw, mediar)       3       394.0

# %% [markdown]
# ## Tercera Configuracion

# %%
association_rules3 = apriori(df, min_support=0.1,use_colnames=True)
association_rules3['length']=association_rules3['itemsets'].apply(lambda x: len(x))
association_rules3['frecuencia']=association_rules3['support']*len(data.index)
association_rules3
# Out:
#     support                  itemsets  length  frecuencia
# 0     0.215                   (altam)       1       215.0
# 1     0.319                   (altar)       1       319.0
# 2     0.303                   (altaw)       1       303.0
# 3     0.154                   (bajam)       1       154.0
# 4     0.119                   (bajaw)       1       119.0
# 5     0.610                  (mediam)       1       610.0
# 6     0.584                  (mediar)       1       584.0
# 7     0.573                  (mediaw)       1       573.0
# 8     0.173            (altam, altar)       2       173.0
# 9     0.160            (altam, altaw)       2       160.0
# 10    0.264            (altaw, altar)       2       264.0
# 11    0.135           (mediam, altar)       2       135.0
# 12    0.132           (mediam, altaw)       2       132.0
# 13    0.446          (mediam, mediar)       2       446.0
# 14    0.435          (mediam, mediaw)       2       435.0
# 15    0.506          (mediaw, mediar)       2       506.0
# 16    0.153     (altaw, altam, altar)       3       153.0
# 17    0.101    (altaw, mediam, altar)       3       101.0
# 18    0.394  (mediam, mediaw, mediar)       3       394.0

# %% [markdown]
# ## ¿Que diferencias hay entre usar soporte y frecuencia?

# %% [markdown]
# ### Soporte

# %%
#Establecemos las mismas condiciones en los dos casos para valorar la diferencia
association_rules1[ (association_rules1['length'] == 3) &
                   (association_rules1['support'] >= 0.001) ]
# Out:
#     support                           itemsets  length  frecuencia
# 42    0.153              (altaw, altam, altar)       3       153.0
# 43    0.020             (mediaw, altam, altar)       3        20.0
# 44    0.007             (altam, altaw, mediar)       3         7.0
# 45    0.035            (altam, mediaw, mediar)       3        35.0
# 46    0.101             (altaw, mediam, altar)       3       101.0
# 47    0.034            (mediam, mediaw, altar)       3        34.0
# 48    0.001             (mediar, altaw, bajam)       3         1.0
# 49    0.031            (mediam, altaw, mediar)       3        31.0
# 50    0.053              (bajaw, bajar, bajam)       3        53.0
# 51    0.005             (bajar, mediaw, bajam)       3         5.0
# 52    0.001          (muy bajaw, bajar, bajam)       3         1.0
# 53    0.018             (bajaw, mediar, bajam)       3        18.0
# 54    0.074            (mediar, mediaw, bajam)       3        74.0
# 55    0.002      (muy bajar, muy bajaw, bajam)       3         2.0
# 56    0.022             (mediam, bajaw, bajar)       3        22.0
# 57    0.005          (bajar, bajaw, muy bajam)       3         5.0
# 58    0.007            (mediam, bajar, mediaw)       3         7.0
# 59    0.021            (mediam, bajaw, mediar)       3        21.0
# 60    0.394           (mediam, mediaw, mediar)       3       394.0
# 61    0.002  (muy bajaw, muy bajar, muy bajam)       3         2.0

# %% [markdown]
# ### Frecuencia

# %%
association_rules1[ (association_rules1['length'] == 3) &
                   (association_rules1['frecuencia'] >= 0.001) ]
# Out:
#     support                           itemsets  length  frecuencia
# 42    0.153              (altaw, altam, altar)       3       153.0
# 43    0.020             (mediaw, altam, altar)       3        20.0
# 44    0.007             (altam, altaw, mediar)       3         7.0
# 45    0.035            (altam, mediaw, mediar)       3        35.0
# 46    0.101             (altaw, mediam, altar)       3       101.0
# 47    0.034            (mediam, mediaw, altar)       3        34.0
# 48    0.001             (mediar, altaw, bajam)       3         1.0
# 49    0.031            (mediam, altaw, mediar)       3        31.0
# 50    0.053              (bajaw, bajar, bajam)       3        53.0
# 51    0.005             (bajar, mediaw, bajam)       3         5.0
# 52    0.001          (muy bajaw, bajar, bajam)       3         1.0
# 53    0.018             (bajaw, mediar, bajam)       3        18.0
# 54    0.074            (mediar, mediaw, bajam)       3        74.0
# 55    0.002      (muy bajar, muy bajaw, bajam)       3         2.0
# 56    0.022             (mediam, bajaw, bajar)       3        22.0
# 57    0.005          (bajar, bajaw, muy bajam)       3         5.0
# 58    0.007            (mediam, bajar, mediaw)       3         7.0
# 59    0.021            (mediam, bajaw, mediar)       3        21.0
# 60    0.394           (mediam, mediaw, mediar)       3       394.0
# 61    0.002  (muy bajaw, muy bajar, muy bajam)       3         2.0

# %% [markdown]
# La frecuencia es el numero de veces que aparece un itemset en el dataset y el soporte es la frecuencia entre el numero de transacciones del dataframe.
# Por lo tanto no hay ninguna diferencia.

# %%
#Representacion 1 
plt.scatter(association_rules1['support'], association_rules1['frecuencia'], alpha=0.5)
plt.xlabel('support')
plt.ylabel('frecuencia')
plt.title('Support vs frecuencia')
plt.show()

# %%
#Representacion 2
fit = np.polyfit(association_rules1['support'], association_rules1['frecuencia'], 1)
fit_fn = np.poly1d(fit)
plt.plot(association_rules1['support'], association_rules1['frecuencia'], 'yo', association_rules1['support'], 
 fit_fn(association_rules1['support']))
# Out:
# [<matplotlib.lines.Line2D at 0x7ffd6886b520>,
#  <matplotlib.lines.Line2D at 0x7ffd6886b430>]

# %% [markdown]
# ## ¿Qué tipo reglas desaparecen según la configuración usada y el tipo de puntuación? ¿Por qué?

# %% [markdown]
# Desaparecen las reglas que no cumplen con los requerimientos impuestos por la configuracion. Porque no cumplen la condiciones de la configuracion.

# %% [markdown]
# ## Para una de las configuraciones, interpreta algunas de las reglas que te hayan resultado curiosas obtenidas usando la clase association_rules y un par de configuraciones cambiando la variable metric y min_threshold.

# %%
#Dada la primera configuracion cambiamos la varaible metric y el treshold
rules1 = association_rules(association_rules1, metric="confidence", min_threshold=0.6)
rules1.head()
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (altam)     (altar)               0.215               0.319    0.173
# 1     (altam)     (altaw)               0.215               0.303    0.160
# 2     (altaw)     (altar)               0.303               0.319    0.264
# 3     (altar)     (altaw)               0.319               0.303    0.264
# 4     (bajar)     (bajam)               0.093               0.154    0.059
#
#    confidence      lift  leverage  conviction
# 0    0.804651  2.522417  0.104415    3.486071
# 1    0.744186  2.456060  0.094855    2.724636
# 2    0.871287  2.731308  0.167343    5.290846
# 3    0.827586  2.731308  0.167343    4.042600
# 4    0.634409  4.119536  0.044678    2.314059

# %%
rules12 = association_rules(association_rules1, metric="lift", min_threshold=0.4)
rules12.head()
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (altam)     (altar)               0.215               0.319    0.173
# 1     (altar)     (altam)               0.319               0.215    0.173
# 2     (altam)     (altaw)               0.215               0.303    0.160
# 3     (altaw)     (altam)               0.303               0.215    0.160
# 4     (altam)    (mediaw)               0.215               0.573    0.055
#
#    confidence      lift  leverage  conviction
# 0    0.804651  2.522417  0.104415    3.486071
# 1    0.542320  2.522417  0.104415    1.715171
# 2    0.744186  2.456060  0.094855    2.724636
# 3    0.528053  2.456060  0.094855    1.663322
# 4    0.255814  0.446447 -0.068195    0.573781

# %% [markdown]
# Podemos ver que al cambiar la metrica de confianza a lift, siendo lift el soporte entre la confianza, la primera regla tiene el mismo valor de lift que la segunda, teniendo esta segunda mucha mas confianza. Ocurre el mismo caso con la tercera y la cuarta regla.

# %% [markdown]
# ## Dadas las mejores configuraciones para cada tipo de puntuación.¿Existen reglas o patrones que se repitan? ¿Podemos generalizar de alguna manera como se comportan los mejores y peores estudiantes?

# %%
# Todo el dataset
association_rulesbest = apriori(df, min_support=0.001,use_colnames=True)
association_rulesbest['length']=association_rulesbest['itemsets'].apply(lambda x: len(x))
association_rulesbest['frecuencia']=association_rulesbest['support']*len(data.index)
association_rulesbest = association_rules(association_rules1, metric="confidence", min_threshold=0.6)

# %% [markdown]
# Reading

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'muy bajar'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#                antecedents  consequents  antecedent support  \
# 47  (muy bajaw, muy bajam)  (muy bajar)               0.002
#
#     consequent support  support  confidence   lift  leverage  conviction
# 47               0.004    0.002         1.0  250.0  0.001992         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'bajar'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#            antecedents consequents  antecedent support  consequent support  \
# 39  (bajaw, muy bajam)     (bajar)               0.005               0.093
#
#     support  confidence       lift  leverage  conviction
# 39    0.005         1.0  10.752688  0.004535         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'mediar'}]
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 27  (altaw, bajam)    (mediar)               0.001               0.584
#
#     support  confidence      lift  leverage  conviction
# 27    0.001         1.0  1.712329  0.000416         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'altar'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 19  (altam, altaw)     (altar)                0.16               0.319
#
#     support  confidence      lift  leverage  conviction
# 19    0.153     0.95625  2.997649   0.10196   15.565714

# %% [markdown]
# Math

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'muy bajam'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'bajam'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#            antecedents consequents  antecedent support  consequent support  \
# 32  (muy bajaw, bajar)     (bajam)               0.001               0.154
#
#     support  confidence      lift  leverage  conviction
# 32    0.001         1.0  6.493506  0.000846         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'mediam'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 28  (altaw, mediar)    (mediam)               0.039                0.61
#
#     support  confidence      lift  leverage  conviction
# 28    0.031    0.794872  1.303069   0.00721     1.90125

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'altam'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# Writing

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'muy bajaw'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#     antecedents  consequents  antecedent support  consequent support  support  \
# 18  (muy bajar)  (muy bajaw)               0.004               0.005    0.004
#
#     confidence   lift  leverage  conviction
# 18         1.0  200.0   0.00398         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'bajaw'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#            antecedents consequents  antecedent support  consequent support  \
# 38  (bajar, muy bajam)     (bajaw)               0.005               0.119
#
#     support  confidence      lift  leverage  conviction
# 38    0.005         1.0  8.403361  0.004405         inf

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'mediaw'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#          antecedents consequents  antecedent support  consequent support  \
# 42  (mediam, mediar)    (mediaw)               0.446               0.573
#
#     support  confidence      lift  leverage  conviction
# 42    0.394    0.883408  1.541724  0.138442    3.662346

# %%
targeted_rules = association_rulesbest[association_rulesbest['consequents'] == {'altaw'}].copy()
targeted_rules.sort_values(by='confidence',ascending=False).head(1)
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 20  (altam, altar)     (altaw)               0.173               0.303
#
#     support  confidence      lift  leverage  conviction
# 20    0.153    0.884393  2.918789  0.100581     6.02905

# %% [markdown]
# Suponiendo que la mejor configuracion hace referencia a la regla con mayor confianza, podemos afirmar que en el caso de que en dos de las asignaturas sea bajo, medio o alto en la asignatura restante sera bajo, medio o alto de la misma forma. Tambien podemos afirmar que en el caso de que en dos asignaturas sea bajo y muy bajo la asignatura restante sera bajo de la misma forma que si en dos asignaturas es muy alto y alto en la restante sera alto.

# %% [markdown]
# # Segunda parte

# %%
#Utilizamos el algoritmo de apriori
association_rules1 = apriori(df,min_support=0.001,use_colnames=True)
association_rules1['length']=association_rules1['itemsets'].apply(lambda x: len(x))
association_rules1['frecuencia']=association_rules1['support']*len(data.index)

# %% [markdown]
# ## Empezaremos obteniendo los itemsets frecuentes para k=1. En este punto necesitaremos obtener el soporte de los itemset.

# %%
association_rules1[ (association_rules1['length'] == 1)]
# Out:
#     support     itemsets  length  frecuencia
# 0     0.215      (altam)       1       215.0
# 1     0.319      (altar)       1       319.0
# 2     0.303      (altaw)       1       303.0
# 3     0.154      (bajam)       1       154.0
# 4     0.093      (bajar)       1        93.0
# 5     0.119      (bajaw)       1       119.0
# 6     0.610     (mediam)       1       610.0
# 7     0.584     (mediar)       1       584.0
# 8     0.573     (mediaw)       1       573.0
# 9     0.007  (muy bajam)       1         7.0
# 10    0.004  (muy bajar)       1         4.0
# 11    0.005  (muy bajaw)       1         5.0

# %% [markdown]
# ## A partir de k=2 mostrar items candidatos y soporte

# %%
association_rules1[ (association_rules1['length'] == 2)]
# Out:
#     support                itemsets  length  frecuencia
# 12    0.173          (altam, altar)       2       173.0
# 13    0.160          (altam, altaw)       2       160.0
# 14    0.042         (altam, mediar)       2        42.0
# 15    0.055         (altam, mediaw)       2        55.0
# 16    0.264          (altaw, altar)       2       264.0
# 17    0.135         (mediam, altar)       2       135.0
# 18    0.055         (mediaw, altar)       2        55.0
# 19    0.001          (altaw, bajam)       2         1.0
# 20    0.132         (mediam, altaw)       2       132.0
# 21    0.039         (altaw, mediar)       2        39.0
# 22    0.059          (bajar, bajam)       2        59.0
# 23    0.071          (bajaw, bajam)       2        71.0
# 24    0.093         (mediar, bajam)       2        93.0
# 25    0.079         (mediaw, bajam)       2        79.0
# 26    0.002      (muy bajar, bajam)       2         2.0
# 27    0.003      (muy bajaw, bajam)       2         3.0
# 28    0.080          (bajaw, bajar)       2        80.0
# 29    0.029         (mediam, bajar)       2        29.0
# 30    0.012         (bajar, mediaw)       2        12.0
# 31    0.005      (bajar, muy bajam)       2         5.0
# 32    0.001      (muy bajaw, bajar)       2         1.0
# 33    0.043         (mediam, bajaw)       2        43.0
# 34    0.039         (bajaw, mediar)       2        39.0
# 35    0.005      (bajaw, muy bajam)       2         5.0
# 36    0.446        (mediam, mediar)       2       446.0
# 37    0.435        (mediam, mediaw)       2       435.0
# 38    0.506        (mediaw, mediar)       2       506.0
# 39    0.002  (muy bajar, muy bajam)       2         2.0
# 40    0.002  (muy bajaw, muy bajam)       2         2.0
# 41    0.004  (muy bajaw, muy bajar)       2         4.0

# %% [markdown]
# ## Repetir el proceso hasta que no se muestren items frecuentes

# %%
association_rules1[ (association_rules1['length'] == 3)]
# Out:
#     support                           itemsets  length  frecuencia
# 42    0.153              (altaw, altam, altar)       3       153.0
# 43    0.020             (mediaw, altam, altar)       3        20.0
# 44    0.007             (altam, altaw, mediar)       3         7.0
# 45    0.035            (altam, mediaw, mediar)       3        35.0
# 46    0.101             (altaw, mediam, altar)       3       101.0
# 47    0.034            (mediam, mediaw, altar)       3        34.0
# 48    0.001             (mediar, altaw, bajam)       3         1.0
# 49    0.031            (mediam, altaw, mediar)       3        31.0
# 50    0.053              (bajaw, bajar, bajam)       3        53.0
# 51    0.005             (bajar, mediaw, bajam)       3         5.0
# 52    0.001          (muy bajaw, bajar, bajam)       3         1.0
# 53    0.018             (bajaw, mediar, bajam)       3        18.0
# 54    0.074            (mediar, mediaw, bajam)       3        74.0
# 55    0.002      (muy bajar, muy bajaw, bajam)       3         2.0
# 56    0.022             (mediam, bajaw, bajar)       3        22.0
# 57    0.005          (bajar, bajaw, muy bajam)       3         5.0
# 58    0.007            (mediam, bajar, mediaw)       3         7.0
# 59    0.021            (mediam, bajaw, mediar)       3        21.0
# 60    0.394           (mediam, mediaw, mediar)       3       394.0
# 61    0.002  (muy bajaw, muy bajar, muy bajam)       3         2.0

# %%
# Se dejan de mostrat items frecuentes a partir de k=4
association_rules1[ (association_rules1['length'] == 4)]
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, frecuencia]
# Index: []

# %% [markdown]
# ## Mostrar todas las posibles reglas con la confianza de cada una de ellas.

# %%
rules1 = association_rules(association_rules1, metric="confidence")
rules1
# Out:
#                antecedents  consequents  antecedent support  \
# 0                  (altam)      (altar)               0.215
# 1                  (altaw)      (altar)               0.303
# 2                  (altar)      (altaw)               0.319
# 3                  (bajar)      (bajaw)               0.093
# 4                 (mediaw)     (mediar)               0.573
# 5                 (mediar)     (mediaw)               0.584
# 6              (muy bajaw)  (muy bajar)               0.005
# 7              (muy bajar)  (muy bajaw)               0.004
# 8           (altam, altaw)      (altar)               0.160
# 9           (altam, altar)      (altaw)               0.173
# 10         (altam, mediar)     (mediaw)               0.042
# 11          (altaw, bajam)     (mediar)               0.001
# 12          (bajar, bajam)      (bajaw)               0.059
# 13      (muy bajaw, bajar)      (bajam)               0.001
# 14         (mediaw, bajam)     (mediar)               0.079
# 15      (muy bajar, bajam)  (muy bajaw)               0.002
# 16      (bajar, muy bajam)      (bajaw)               0.005
# 17      (bajaw, muy bajam)      (bajar)               0.005
# 18        (mediam, mediaw)     (mediar)               0.435
# 19        (mediam, mediar)     (mediaw)               0.446
# 20  (muy bajaw, muy bajam)  (muy bajar)               0.002
# 21  (muy bajar, muy bajam)  (muy bajaw)               0.002
#
#     consequent support  support  confidence        lift  leverage  conviction
# 0                0.319    0.173    0.804651    2.522417  0.104415    3.486071
# 1                0.319    0.264    0.871287    2.731308  0.167343    5.290846
# 2                0.303    0.264    0.827586    2.731308  0.167343    4.042600
# 3                0.119    0.080    0.860215    7.228698  0.068933    6.302538
# 4                0.584    0.506    0.883072    1.512109  0.171368    3.557731
# 5                0.573    0.506    0.866438    1.512109  0.171368    3.197026
# 6                0.004    0.004    0.800000  200.000000  0.003980    4.980000
# 7                0.005    0.004    1.000000  200.000000  0.003980         inf
# 8                0.319    0.153    0.956250    2.997649  0.101960   15.565714
# 9                0.303    0.153    0.884393    2.918789  0.100581    6.029050
# 10               0.573    0.035    0.833333    1.454334  0.010934    2.562000
# 11               0.584    0.001    1.000000    1.712329  0.000416         inf
# 12               0.119    0.053    0.898305    7.548782  0.045979    8.663167
# 13               0.154    0.001    1.000000    6.493506  0.000846         inf
# 14               0.584    0.074    0.936709    1.603954  0.027864    6.572800
# 15               0.005    0.002    1.000000  200.000000  0.001990         inf
# 16               0.119    0.005    1.000000    8.403361  0.004405         inf
# 17               0.093    0.005    1.000000   10.752688  0.004535         inf
# 18               0.584    0.394    0.905747    1.550937  0.139960    4.413659
# 19               0.573    0.394    0.883408    1.541724  0.138442    3.662346
# 20               0.004    0.002    1.000000  250.000000  0.001992         inf
# 21               0.005    0.002    1.000000  200.000000  0.001990         inf

# %% [markdown]
# ## Listar todas las reglas que sean de alta confianza.

# %%
# Suponemos que las reglas de alta confianza son a partir de 0.7 de confianza
rules1[ (0.7<=rules1['confidence'])].sort_values(by='confidence',ascending=False)
# Out:
#                antecedents  consequents  antecedent support  \
# 11          (altaw, bajam)     (mediar)               0.001
# 7              (muy bajar)  (muy bajaw)               0.004
# 20  (muy bajaw, muy bajam)  (muy bajar)               0.002
# 17      (bajaw, muy bajam)      (bajar)               0.005
# 16      (bajar, muy bajam)      (bajaw)               0.005
# 15      (muy bajar, bajam)  (muy bajaw)               0.002
# 13      (muy bajaw, bajar)      (bajam)               0.001
# 21  (muy bajar, muy bajam)  (muy bajaw)               0.002
# 8           (altam, altaw)      (altar)               0.160
# 14         (mediaw, bajam)     (mediar)               0.079
# 18        (mediam, mediaw)     (mediar)               0.435
# 12          (bajar, bajam)      (bajaw)               0.059
# 9           (altam, altar)      (altaw)               0.173
# 19        (mediam, mediar)     (mediaw)               0.446
# 4                 (mediaw)     (mediar)               0.573
# 1                  (altaw)      (altar)               0.303
# 5                 (mediar)     (mediaw)               0.584
# 3                  (bajar)      (bajaw)               0.093
# 10         (altam, mediar)     (mediaw)               0.042
# 2                  (altar)      (altaw)               0.319
# 0                  (altam)      (altar)               0.215
# 6              (muy bajaw)  (muy bajar)               0.005
#
#     consequent support  support  confidence        lift  leverage  conviction
# 11               0.584    0.001    1.000000    1.712329  0.000416         inf
# 7                0.005    0.004    1.000000  200.000000  0.003980         inf
# 20               0.004    0.002    1.000000  250.000000  0.001992         inf
# 17               0.093    0.005    1.000000   10.752688  0.004535         inf
# 16               0.119    0.005    1.000000    8.403361  0.004405         inf
# 15               0.005    0.002    1.000000  200.000000  0.001990         inf
# 13               0.154    0.001    1.000000    6.493506  0.000846         inf
# 21               0.005    0.002    1.000000  200.000000  0.001990         inf
# 8                0.319    0.153    0.956250    2.997649  0.101960   15.565714
# 14               0.584    0.074    0.936709    1.603954  0.027864    6.572800
# 18               0.584    0.394    0.905747    1.550937  0.139960    4.413659
# 12               0.119    0.053    0.898305    7.548782  0.045979    8.663167
# 9                0.303    0.153    0.884393    2.918789  0.100581    6.029050
# 19               0.573    0.394    0.883408    1.541724  0.138442    3.662346
# 4                0.584    0.506    0.883072    1.512109  0.171368    3.557731
# 1                0.319    0.264    0.871287    2.731308  0.167343    5.290846
# 5                0.573    0.506    0.866438    1.512109  0.171368    3.197026
# 3                0.119    0.080    0.860215    7.228698  0.068933    6.302538
# 10               0.573    0.035    0.833333    1.454334  0.010934    2.562000
# 2                0.303    0.264    0.827586    2.731308  0.167343    4.042600
# 0                0.319    0.173    0.804651    2.522417  0.104415    3.486071
# 6                0.004    0.004    0.800000  200.000000  0.003980    4.980000

# %% [markdown]
# ## Dado un antecesor, devolver todas las reglas que contengan a dicho antecesor.

# %%
# El antecesor seleccionado es mediar
targeted_rules = rules1[rules1['antecedents'] == {'mediar'}].copy()
targeted_rules
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 5    (mediar)    (mediaw)               0.584               0.573    0.506
#
#    confidence      lift  leverage  conviction
# 5    0.866438  1.512109  0.171368    3.197026

# %% [markdown]
# ## Dado un umbral mínimo devolver todas las reglas que cumplan con dicha confianza.

# %%
# Umbral minimo de 0.7 de confianza teniendo en cuenta el antecesor
targeted_rules[0.7<targeted_rules['confidence']]
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 5    (mediar)    (mediaw)               0.584               0.573    0.506
#
#    confidence      lift  leverage  conviction
# 5    0.866438  1.512109  0.171368    3.197026

# %%
#Sin tener en cuenta el antecesor
rules1[0.7<rules1['confidence']]
# Out:
#                antecedents  consequents  antecedent support  \
# 0                  (altam)      (altar)               0.215
# 1                  (altaw)      (altar)               0.303
# 2                  (altar)      (altaw)               0.319
# 3                  (bajar)      (bajaw)               0.093
# 4                 (mediaw)     (mediar)               0.573
# 5                 (mediar)     (mediaw)               0.584
# 6              (muy bajaw)  (muy bajar)               0.005
# 7              (muy bajar)  (muy bajaw)               0.004
# 8           (altam, altaw)      (altar)               0.160
# 9           (altam, altar)      (altaw)               0.173
# 10         (altam, mediar)     (mediaw)               0.042
# 11          (altaw, bajam)     (mediar)               0.001
# 12          (bajar, bajam)      (bajaw)               0.059
# 13      (muy bajaw, bajar)      (bajam)               0.001
# 14         (mediaw, bajam)     (mediar)               0.079
# 15      (muy bajar, bajam)  (muy bajaw)               0.002
# 16      (bajar, muy bajam)      (bajaw)               0.005
# 17      (bajaw, muy bajam)      (bajar)               0.005
# 18        (mediam, mediaw)     (mediar)               0.435
# 19        (mediam, mediar)     (mediaw)               0.446
# 20  (muy bajaw, muy bajam)  (muy bajar)               0.002
# 21  (muy bajar, muy bajam)  (muy bajaw)               0.002
#
#     consequent support  support  confidence        lift  leverage  conviction
# 0                0.319    0.173    0.804651    2.522417  0.104415    3.486071
# 1                0.319    0.264    0.871287    2.731308  0.167343    5.290846
# 2                0.303    0.264    0.827586    2.731308  0.167343    4.042600
# 3                0.119    0.080    0.860215    7.228698  0.068933    6.302538
# 4                0.584    0.506    0.883072    1.512109  0.171368    3.557731
# 5                0.573    0.506    0.866438    1.512109  0.171368    3.197026
# 6                0.004    0.004    0.800000  200.000000  0.003980    4.980000
# 7                0.005    0.004    1.000000  200.000000  0.003980         inf
# 8                0.319    0.153    0.956250    2.997649  0.101960   15.565714
# 9                0.303    0.153    0.884393    2.918789  0.100581    6.029050
# 10               0.573    0.035    0.833333    1.454334  0.010934    2.562000
# 11               0.584    0.001    1.000000    1.712329  0.000416         inf
# 12               0.119    0.053    0.898305    7.548782  0.045979    8.663167
# 13               0.154    0.001    1.000000    6.493506  0.000846         inf
# 14               0.584    0.074    0.936709    1.603954  0.027864    6.572800
# 15               0.005    0.002    1.000000  200.000000  0.001990         inf
# 16               0.119    0.005    1.000000    8.403361  0.004405         inf
# 17               0.093    0.005    1.000000   10.752688  0.004535         inf
# 18               0.584    0.394    0.905747    1.550937  0.139960    4.413659
# 19               0.573    0.394    0.883408    1.541724  0.138442    3.662346
# 20               0.004    0.002    1.000000  250.000000  0.001992         inf
# 21               0.005    0.002    1.000000  200.000000  0.001990         inf

# %% [markdown]
# ## Utiliza al menos dos representaciones gráficas para representar las reglas obtenidas e interpretar los datos.

# %%
# Subplot con dos representaciones
# La primera se trata de un grafico de barras de dos variables, el soporte y la confianza
# La segunda representamos unicamente el lift para poder bien la relacion entre los datos
fig, axes = plt.subplots(nrows=2, ncols=1)
rules1[["support","confidence"]].plot(ax=axes[0],figsize=(15, 8), kind='bar')
rules1[["lift"]].plot(ax=axes[1],figsize=(15, 8), kind='bar');

# %% [markdown]
# Podemos ver que en los casos que el support es alto, el lift es bajo y en los casos que la confianza es alta y el soporte es bajo, el lift es alto. Tal y como podiamos esperar segun la formula. lift=soporte/confianza.
